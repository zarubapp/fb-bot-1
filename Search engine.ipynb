# %% [markdown]
# Загружаем модули

# %%
import zipfile
from io import BytesIO, StringIO
from IPython.display import display

import pandas as pd
import requests
import hashlib
import fsspec

# %% [markdown]
# Задаем значения

# %%
url = 'https://flibusta.site/catalog/catalog.zip'

md5hash_current = ''

# %% [markdown]
# Получаем файл с данными

# %%
r = requests.get(url)
print(r.status_code)
# Out:
# 200

# %% [markdown]
# Распаковываем файл, перекодируем и читаем дата фрейм

# %%
zipDocument = zipfile.ZipFile(BytesIO(r.content))
file = zipDocument.open('catalog.txt').read().decode('utf-8')

df = pd.read_csv(StringIO(file), delimiter=';', on_bad_lines='skip')

# %%
display(df)
# Out:
#        Last Name First Name Middle Name  \
# 0            NaN        NaN         NaN
# 1            NaN        NaN         NaN
# 2            NaN        NaN         NaN
# 3            NaN        NaN         NaN
# 4            NaN        NaN         NaN
# ...          ...        ...         ...
# 617869     我吃西红柿          .         NaN
# 617870       文抄公          .         NaN
# 617871       梁晓声        NaN         NaN
# 617872        滚开          .         NaN
# 617873      파르나르        NaN         NaN
#
#                                                     Title  \
# 0       АТЛАС И РУКОВОДСТВО ПО РЕФЛЕКСОТЕРАПИ;;ru;;;52...
# 1                                          Если, 2010, №5
# 2                        Иностранная литература, 2018, №1
# 3                        Иностранная литература, 2019, №7
# 4                       Иностранная литература, №2, 2017.
# ...                                                   ...
# 617869              Извивающийся дракон Том 9, Глава 1-50
# 617870                          Чернокнижник в мире магов
# 617871                                           一个红卫兵的自白
# 617872                                          Мир магов
# 617873                        Ублюдочный герой FFF-класса
#
#                                                  Subtitle Language    Year  \
# 0                                                     NaN       ru  1989.0
# 1                                                     NaN       ru  2010.0
# 2                                                     NaN       ru  2018.0
# 3                                                     NaN       ru  2019.0
# 4                                                     NaN       ru  2017.0
# ...                                                   ...      ...     ...
# 617869                                                 ЛП       ru     NaN
# 617870                                          ranobe.me       ru     NaN
# 617871                                                NaN       zh  2006.0
# 617872                                                NaN       ru     NaN
# 617873  ЛП, FFF-Class Trashero / Главы 1 - 46 (исходны...       ru  2018.0
#
#                        Series      ID
# 0                         NaN  582436
# 1                         NaN  587243
# 2                         NaN  577533
# 3                         NaN  571088
# 4                         NaN  566586
# ...                       ...     ...
# 617869  Извивающийся дракон 9  572493
# 617870                    NaN  556152
# 617871                    NaN  511903
# 617872                    NaN  556153
# 617873                    NaN  553132
#
# [617874 rows x 9 columns]

# %% [markdown]
# Поисковая фраза

# %%
Search_author = 'азимов'
book_name = ''

#search_string = ['foo', 'baz']
#search_string = 'Красный кефир'.split()
search_string = 'красный кефир'

display(search_string)

#df_result = df[df['Title'].str.contains(search_string, na=False, case=False)]
df_result = df[df['Last Name'].str.contains(Search_author, na=False, case=False)]
# Out:
# 'красный кефир'

# %%
display(df_result.info())
display(df_result.tail(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1046 entries, 39469 to 381552
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Last Name    1046 non-null   object
#  1   First Name   1046 non-null   object
#  2   Middle Name  37 non-null     object
#  3   Title        1046 non-null   object
#  4   Subtitle     403 non-null    object
#  5   Language     1046 non-null   object
#  6   Year         723 non-null    float64
#  7   Series       815 non-null    object
#  8   ID           1046 non-null   int64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 81.7+ KB
# None
#               Last Name  First Name  Middle Name                 Title  \
# 92435   Борисов-Назимов  Константин  Геннадьевич    Развивающий скачок
# 92436   Борисов-Назимов  Константин  Геннадьевич  Свольн. Путь в воины
# 92437   Борисов-Назимов  Константин  Геннадьевич            Смотритель
# 92438   Борисов-Назимов  Константин  Геннадьевич       Спасти драконов
# 92439   Борисов-Назимов  Константин  Геннадьевич                 Старт
# 92440   Борисов-Назимов  Константин  Геннадьевич               Травник
# 92441   Борисов-Назимов  Константин  Геннадьевич         Хозяин Сибири
# 92442   Борисов-Назимов  Константин  Геннадьевич            Шаг к цели
# 92443   Борисов-Назимов  Константин  Геннадьевич  Школа истинных магов
# 381552         Назимова     Людмила          NaN             Круг зари
#
#          Subtitle Language    Year  \
# 92435         NaN       ru     NaN
# 92436   СИ litres       ru  2020.0
# 92437         NaN       ru  2019.0
# 92438         NaN       ru  2012.0
# 92439          СИ       ru  2018.0
# 92440         NaN       ru  2021.0
# 92441      litres       ru  2020.0
# 92442      litres       ru  2019.0
# 92443         NaN       ru  2014.0
# 381552        NaN       ru  1977.0
#
#                                                    Series      ID
# 92435                                            Cherry 2  608150
# 92436                                Попаданцы - боевик 0  604097
# 92437                                                 NaN  582985
# 92438                                                 NaN  283945
# 92439                                   Гоночный Джокер 1  547891
# 92440                                           Травник 1  621542
# 92441   Охранитель 5|Попаданцы - АИ 0|Фантастическая И...  609215
# 92442   Охранитель 2|Попаданцы - АИ 0|Фантастическая И...  572976
# 92443                          Магия фэнтези 532|Рыскач 3  378597
# 381552                                                NaN  456016
